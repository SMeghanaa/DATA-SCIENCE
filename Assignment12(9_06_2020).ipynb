# %% [markdown]
# <a href="https://colab.research.google.com/github/SMeghanaa/DATA-SCIENCE/blob/master/Assignment12(9_06_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv")

# %%
df
# Out:
#      Match_SK  match_id  ... Win_Margin Country_id
# 0           0    335987  ...      140.0          1
# 1           1    335988  ...       33.0          1
# 2           2    335989  ...        9.0          1
# 3           3    335990  ...        5.0          1
# 4           4    335991  ...        5.0          1
# ..        ...       ...  ...        ...        ...
# 632       632   1082646  ...       10.0          1
# 633       633   1082647  ...       20.0          1
# 634       634   1082648  ...        7.0          1
# 635       635   1082649  ...        6.0          1
# 636       636   1082650  ...        1.0          1
#
# [637 rows x 17 columns]

# %%
d1=df.loc[(df['City_Name']=='Hyderabad')] 
d1.reset_index()
# Out:
#     index  Match_SK  match_id  ...          ManOfMach Win_Margin Country_id
# 0       6         6    335993  ...           V Sehwag        9.0          1
# 1       8         8    335995  ...          YK Pathan        3.0          1
# 2      17        17    336004  ...           SE Marsh        7.0          1
# 3      20        20    336007  ...      R Vinay Kumar        5.0          1
# 4      32        32    336019  ...         SC Ganguly       23.0          1
# 5      42        42    336029  ...           DJ Bravo       25.0          1
# 6      54        54    336042  ...           SK Raina        7.0          1
# 7     176       176    501204  ...         SK Trivedi        8.0          1
# 8     185       185    501213  ...           DW Steyn       33.0          1
# 9     189       189    501217  ...        PC Valthaty        8.0          1
# 10    200       200    501229  ...         SL Malinga       37.0          1
# ...

# %%
d2=d1['ManOfMach'].value_counts()
d2.sort_index(inplace=True)
print(type(d2))




d3=pd.DataFrame(d2).reset_index()
d3.rename(columns={"index":"player"})
# Out:
# <class 'pandas.core.series.Series'>
#                player  ManOfMach
# 0            A Mishra          2
# 1            AB Dinda          1
# 2           AT Rayudu          1
# 3             B Kumar          1
# 4           CH Morris          1
# 5           DA Warner          6
# 6            DJ Bravo          1
# 7           DJG Sammy          1
# 8            DW Steyn          3
# 9           G Gambhir          1
# 10          GH Vihari          2
# 11           I Sharma          1
# 12     MJ McClenaghan          1
# 13           MR Marsh          1
# 14      Mandeep Singh          1
# 15  Mustafizur Rahman          1
# 16           PA Patel          1
# 17        PC Valthaty          1
# 18      R Vinay Kumar          1
# 19         SC Ganguly          1
# 20           SE Marsh          1
# 21           SK Raina          2
# 22         SK Trivedi          1
# 23         SL Malinga          1
# 24           UT Yadav          1
# 25            V Kohli          1
# ...

# %% [markdown]
# Question 2:
# Plot a pie chart for the country_name column

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(df['Country_Name'].value_counts())
# Out:
# India           560
# South Africa     57
# U.A.E            20
# Name: Country_Name, dtype: int64

# %%
count = [560,20,57]
clabels = ["India","U.A.E","South Africa"]
plt.pie(count,labels=clabels,autopct="%1.1f%%",radius=1.5,colors=["blue","red","green"],
        explode=[0,0.1,0.1],startangle=45)
plt.show()
