# %% [markdown]
# <a href="https://colab.research.google.com/github/SMeghanaa/DATA-SCIENCE/blob/master/8-06-2020(class).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/diamonds.csv",nrows=10)

# %%
df
# Out:
#    Unnamed: 0  carat        cut color clarity  ...  table  price     x     y     z
# 0           1   0.23      Ideal     E     SI2  ...    NaN    326  3.95  3.98  2.43
# 1           2   0.21    Premium     E     SI1  ...   61.0    326  3.89   NaN  2.31
# 2           3   0.23       Good     E     VS1  ...   65.0    327  4.05  4.07  2.31
# 3           4   0.29    Premium     I     VS2  ...   58.0    334   NaN  4.23  2.63
# 4           5   0.31       Good     J     SI2  ...   58.0    335  4.34  4.35  2.75
# 5           6   0.24  Very Good     J    VVS2  ...   57.0    336  3.94  3.96  2.48
# 6           7   0.24  Very Good     I    VVS1  ...   57.0    336  3.95  3.98  2.47
# 7           8   0.26  Very Good     H     SI1  ...   55.0    337  4.07  4.11  2.53
# 8           9   0.22       Fair     E     VS2  ...   61.0    337  3.87  3.78  2.49
# 9          10   0.23  Very Good     H     VS1  ...   61.0    338  4.00  4.05  2.39
#
# [10 rows x 11 columns]

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)
df
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5    NaN    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89   NaN  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334   NaN  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# ####Sorting DataFrames
# 1. sort by indices
# 2. sort by values

# %%
df.sort_index(axis=0,ascending=True)           #ascending order
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5    NaN    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89   NaN  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334   NaN  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.sort_index(axis=0,ascending=False)           #Descending order
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 3   0.29    Premium     I     VS2   62.4   58.0    334   NaN  4.23  2.63
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89   NaN  2.31
# 0   0.23      Ideal     E     SI2   61.5    NaN    326  3.95  3.98  2.43

# %%
df.sort_values(by='price',ascending=False)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 3   0.29    Premium     I     VS2   62.4   58.0    334   NaN  4.23  2.63
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0   0.23      Ideal     E     SI2   61.5    NaN    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89   NaN  2.31

# %%
df.sort_values(by='price',ascending=True)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5    NaN    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89   NaN  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334   NaN  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.sort_values(by=['price','depth'],ascending=False)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 3   0.29    Premium     I     VS2   62.4   58.0    334   NaN  4.23  2.63
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0   0.23      Ideal     E     SI2   61.5    NaN    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89   NaN  2.31

# %% [markdown]
# ####Subsetting Rows Based on Conditions

# %%
df.price>335
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: price, dtype: bool

# %%
df.loc[df.price>=335]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.loc[df['price']>=335]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.loc[(df['x']>=3) & (df['y']>3) & (df['z']>2.5)]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53

# %%
cut_type=["Premium","Fair"]
df.loc[(df['cut']=='Premium') | (df['cut']=='Fair')]
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89   NaN  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334   NaN  4.23  2.63
# 8   0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49

# %%
df[df['cut'].isin(cut_type)]
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89   NaN  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334   NaN  4.23  2.63
# 8   0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49

# %% [markdown]
# ####Merging : inner,outer,left,right

# %%
df1 = pd.DataFrame({"branch":['hyd','blr','vizag','pune'],"total":[90,96,98,92]})
df1 
df2 = pd.DataFrame({"branch":['blr','hyd','vizag','chennai'],"distance_from_city":[40,60,12,20]})
df2
# Out:
#     branch  distance_from_city
# 0      blr                  40
# 1      hyd                  60
# 2    vizag                  12
# 3  chennai                  20

# %%
pd.merge(df1,df2,on="branch",how='inner')
# Out:
#   branch  total  distance_from_city
# 0    hyd     90                  60
# 1    blr     96                  40
# 2  vizag     98                  12

# %%
pd.merge(df1,df2,on="branch")         #by default, how value is 'inner'
# Out:
#   branch  total  distance_from_city
# 0    hyd     90                  60
# 1    blr     96                  40
# 2  vizag     98                  12

# %%
pd.merge(df1,df2,on="branch",how='outer')
# Out:
#     branch  total  distance_from_city
# 0      hyd   90.0                60.0
# 1      blr   96.0                40.0
# 2    vizag   98.0                12.0
# 3     pune   92.0                 NaN
# 4  chennai    NaN                20.0

# %%
pd.merge(df1,df2,on="branch",how='left',indicator=True)        #indicates from where the values are taken
# Out:
#   branch  total  distance_from_city     _merge
# 0    hyd     90                60.0       both
# 1    blr     96                40.0       both
# 2  vizag     98                12.0       both
# 3   pune     92                 NaN  left_only

# %%
pd.merge(df1,df2,on="branch",how='right',indicator=True)
# Out:
#     branch  total  distance_from_city      _merge
# 0      hyd   90.0                  60        both
# 1      blr   96.0                  40        both
# 2    vizag   98.0                  12        both
# 3  chennai    NaN                  20  right_only

# %% [markdown]
# ####Row concatenation
# axis=0, rows
# axis=1,column

# %%
df1 = pd.DataFrame({'Name': ['Aman', 'Joy', 'Rashmi', 'Saif'],'Age': ['34', '31', '22', '33'],'Gender': ['M', 'M', 'F', 'M']})
df2 = pd.DataFrame({'Name': ['Akhil', 'Asha', 'Preeti'],'Age': ['31', '22', '23'],'Gender': ['M', 'F', 'F']} )

# %%
pd.concat([df1,df2],axis=0)
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
df1.append(df2)
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
df3 = pd.DataFrame({"Address":['blr','hyd','vizag','chennai'],"Grade":['A','B','C','D']})
df3
# Out:
#    Address Grade
# 0      blr     A
# 1      hyd     B
# 2    vizag     C
# 3  chennai     D

# %%
df1
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M

# %%
pd.concat([df1,df3],axis=1)
# Out:
#      Name Age Gender  Address Grade
# 0    Aman  34      M      blr     A
# 1     Joy  31      M      hyd     B
# 2  Rashmi  22      F    vizag     C
# 3    Saif  33      M  chennai     D

# %%
IPL_2018 = pd.DataFrame({'IPL Team': ['CSK', 'SRH', 'KKR', 'RR', 'MI', 'RCB', 'KXIP', 'DD'],'Matches Played': [16, 17, 16, 15, 14, 14, 14, 14],'Matches Won': [11, 10, 9, 7, 6, 6, 6, 5]})
IPL_2018.set_index('IPL Team', inplace = True)
IPL_2018
# Out:
#           Matches Played  Matches Won
# IPL Team
# CSK                   16           11
# SRH                   17           10
# KKR                   16            9
# RR                    15            7
# MI                    14            6
# RCB                   14            6
# KXIP                  14            6
# DD                    14            5

# %%
IPL_2017 = pd.DataFrame({'IPL Team': ['MI', 'RPS', 'KKR', 'SRH', 'KXIP', 'DD', 'GL', 'RCB'],
                         'Matches Played': [17, 16, 16, 15, 14, 14, 14, 14],
                         'Matches Won': [12, 10, 9, 8, 7, 6, 4, 3]}
                       )
IPL_2017.set_index('IPL Team', inplace = True)
IPL_2017
# Out:
#           Matches Played  Matches Won
# IPL Team
# MI                    17           12
# RPS                   16           10
# KKR                   16            9
# SRH                   15            8
# KXIP                  14            7
# DD                    14            6
# GL                    14            4
# RCB                   14            3

# %%
Total=IPL_2017+IPL_2018
Total
# Out:
#           Matches Played  Matches Won
# IPL Team
# CSK                  NaN          NaN
# DD                  28.0         11.0
# GL                   NaN          NaN
# KKR                 32.0         18.0
# KXIP                28.0         13.0
# MI                  31.0         18.0
# RCB                 28.0          9.0
# RPS                  NaN          NaN
# RR                   NaN          NaN
# SRH                 32.0         18.0

# %%
total=IPL_2018.add(IPL_2017,fill_value=0)
total
# Out:
#           Matches Played  Matches Won
# IPL Team
# CSK                 16.0         11.0
# DD                  28.0         11.0
# GL                  14.0          4.0
# KKR                 32.0         18.0
# KXIP                28.0         13.0
# MI                  31.0         18.0
# RCB                 28.0          9.0
# RPS                 16.0         10.0
# RR                  15.0          7.0
# SRH                 32.0         18.0

# %% [markdown]
# ###Simple Arithmetic operations on two or more dataframes
# 1. add(): +
# 2. sub(): -
# 3. mul(): *
# 4. div(): /
# 5. floordiv(): //
# 6.

# %% [markdown]
# ####groupby() : split,apply,combine:

# %%
data = {"name":['a','b','c','d','e','f'],
       "branch":['hyd','vizag','blr','hyd','vizag','blr'],
       "marks":[90,91,92,93,94,95]}
df = pd.DataFrame(data)
df
# Out:
#   name branch  marks
# 0    a    hyd     90
# 1    b  vizag     91
# 2    c    blr     92
# 3    d    hyd     93
# 4    e  vizag     94
# 5    f    blr     95

# %%
g=df.groupby("branch")
g

# %%
for branch,branch_df in g:
  print(branch)
  print(branch_df)
# Out:
# blr
#   name branch  marks
# 2    c    blr     92
# 5    f    blr     95
# hyd
#   name branch  marks
# 0    a    hyd     90
# 3    d    hyd     93
# vizag
#   name branch  marks
# 1    b  vizag     91
# 4    e  vizag     94

# %%
g.get_group('hyd')["marks"].sum()
# Out:
# 183

# %%
g.get_group('hyd')['marks'].mean()
# Out:
# 91.5

# %%
g.mean()
# Out:
#         marks
# branch
# blr      93.5
# hyd      91.5
# vizag    92.5

# %%
g.describe()
# Out:
#        marks
#        count  mean      std   min    25%   50%    75%   max
# branch
# blr      2.0  93.5  2.12132  92.0  92.75  93.5  94.25  95.0
# hyd      2.0  91.5  2.12132  90.0  90.75  91.5  92.25  93.0
# vizag    2.0  92.5  2.12132  91.0  91.75  92.5  93.25  94.0

# %% [markdown]
# ####Pivot table

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9
